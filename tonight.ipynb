# %%
from models.transportation import *
from models.products.raw import RawMaterialList
from models.products.middle_one import MiddleLevelOneList
from models.products.middle_two import MiddleLevelTwoList
from models.products.final import FinalList
from models.building import *
from main import *

bus = Buss()
ship = Ship()
air_plane = AirPlane()

production = Production()
assembly = Assembly()
recycle = Recycle()
inventory = Inventory()
# Out:
# MiddleLevelOneList
# Modem 2G 690
# DisplayKeypad 1590
# PhoneBattery 816
# PhoneKeypad 2460
# Camera 1200
# Modem3G 950
# PhoneFrame 1380
# TouchDisplay 4800
# MiddleLevelTwoList
# Communication2G 3825
# MediaNoCamera 800
# PhoneBody1 16175
# Communication3G 5550
# MediaSingleCamera 4300
# PhoneBody2 17325
# Final
# GPhone1 54100
# GPhone2 57400
# GPhone3 61500

# %%
from tabulate import tabulate

product = FinalList.GPhone3.value
print(f"{product.name} Data")
print()

print("Buy Mean Sell Max")
data = [["count", "profit percent", "total profit", "cach flow needed"]]
for production_count in range(100, 3001, 100):
    res = get_all_data_mean_max(air_plane, product, production_count, 2)
    data.append([production_count, round(res[0], 2), res[1], res[2]])
print(tabulate(data))

print("Buy Max Sell Max")
data = [["count", "profit percent", "total profit", "cach flow needed"]]
for production_count in range(100, 3001, 100):
    res = get_all_data_max_max(air_plane, product, production_count, 2)
    data.append([production_count, round(res[0], 2), res[1], res[2]])
print(tabulate(data))

print("Buy Min Sell Max")
data = [["count", "profit percent", "total profit", "cach flow needed"]]
for production_count in range(100, 3001, 100):
    res = get_all_data_min_max(air_plane, product, production_count, 2)
    data.append([production_count, round(res[0], 2), res[1], res[2]])
print(tabulate(data))
# Out:
# GPhone3 Data
#
# Buy Mean Sell Max
# -----  --------------  ------------  ----------------
# count  profit percent  total profit  cach flow needed
# 100    -0.42           -9.0          19.0
# 200    -0.14           -4.0          25.0
# 300    0.03            1.0           32.0
# 400    0.15            5.0           38.0
# 500    0.23            10.0          45.0
# 600    0.29            15.0          51.0
# 700    0.34            19.0          57.0
# 800    0.38            24.0          64.0
# 900    0.41            29.0          70.0
# 1000   0.44            33.0          77.0
# 1100   0.46            38.0          83.0
# 1200   0.48            43.0          90.0
# 1300   0.49            47.0          96.0
# 1400   0.51            52.0          103.0
# 1500   0.52            57.0          109.0
# 1600   0.53            61.0          115.0
# 1700   0.54            66.0          122.0
# 1800   0.55            71.0          128.0
# 1900   0.56            75.0          135.0
# 2000   0.57            80.0          141.0
# 2100   0.57            85.0          148.0
# 2200   0.58            89.0          154.0
# 2300   0.59            94.0          160.0
# 2400   0.59            99.0          167.0
# 2500   0.6             103.0         173.0
# 2600   0.6             108.0         180.0
# 2700   0.61            113.0         186.0
# 2800   0.61            117.0         193.0
# 2900   0.61            122.0         199.0
# 3000   0.62            127.0         205.0
# -----  --------------  ------------  ----------------
# Buy Max Sell Max
# -----  --------------  ------------  ----------------
# count  profit percent  total profit  cach flow needed
# 100    -0.45           -10.0         20.0
# 200    -0.2            -6.0          27.0
# 300    -0.06           -3.0          35.0
# 400    0.04            1.0           42.0
# 500    0.1             5.0           50.0
# 600    0.15            8.0           57.0
# 700    0.19            12.0          65.0
# 800    0.22            16.0          72.0
# 900    0.25            19.0          80.0
# 1000   0.27            23.0          87.0
# 1100   0.28            26.0          95.0
# 1200   0.3             30.0          102.0
# 1300   0.31            34.0          110.0
# 1400   0.32            37.0          117.0
# 1500   0.33            41.0          124.0
# 1600   0.34            45.0          132.0
# 1700   0.35            48.0          139.0
# 1800   0.36            52.0          147.0
# 1900   0.36            56.0          154.0
# 2000   0.37            59.0          162.0
# 2100   0.37            63.0          169.0
# 2200   0.38            66.0          177.0
# 2300   0.38            70.0          184.0
# 2400   0.39            74.0          192.0
# 2500   0.39            77.0          199.0
# 2600   0.39            81.0          207.0
# 2700   0.4             85.0          214.0
# 2800   0.4             88.0          222.0
# 2900   0.4             92.0          229.0
# 3000   0.41            96.0          236.0
# -----  --------------  ------------  ----------------
# Buy Min Sell Max
# -----  --------------  ------------  ----------------
# count  profit percent  total profit  cach flow needed
# 100    -0.39           -8.0          18.0
# 200    -0.06           -2.0          23.0
# 300    0.14            4.0           29.0
# 400    0.29            9.0           34.0
# 500    0.39            15.0          39.0
# 600    0.47            21.0          45.0
# 700    0.53            26.0          50.0
# 800    0.58            32.0          56.0
# 900    0.62            38.0          61.0
# 1000   0.66            44.0          66.0
# 1100   0.69            49.0          72.0
# 1200   0.71            55.0          77.0
# 1300   0.74            61.0          83.0
# 1400   0.75            66.0          88.0
# 1500   0.77            72.0          93.0
# 1600   0.79            78.0          99.0
# 1700   0.8             83.0          104.0
# 1800   0.81            89.0          110.0
# 1900   0.83            95.0          115.0
# 2000   0.84            101.0         120.0
# 2100   0.85            106.0         126.0
# 2200   0.85            112.0         131.0
# 2300   0.86            118.0         137.0
# 2400   0.87            123.0         142.0
# 2500   0.88            129.0         147.0
# 2600   0.88            135.0         153.0
# 2700   0.89            141.0         158.0
# 2800   0.89            146.0         164.0
# 2900   0.9             152.0         169.0
# 3000   0.9             158.0         174.0
# -----  --------------  ------------  ----------------
